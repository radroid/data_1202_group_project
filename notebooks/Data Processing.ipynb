# %% [markdown]
# # Exploratory Data Analysis of the Spotify Top 200 Charts
# In ths notebook, we will explore Spotify's Top 200 Charts by **region** and **date**. The dataset is scarped from [Spotify's official Top Charts Website](https://spotifycharts.com/regional/).

# %%
# Import required libraries
import pandas as pd
import numpy as np
import pathlib

# %%
# Load the dataset
filepath = pathlib.Path("data/all_regions_top_200_daily.csv")

if filepath.exists():
    data_df = pd.read_csv(filepath, parse_dates=True)
else:
    data_df = pd.DataFrame()
    
data_df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17703738 entries, 0 to 17703737
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Position    float64
#  1   Track Name  object
#  2   Artist      object
#  3   Streams     float64
#  4   date        object
#  5   region      object
#  6   spotify_id  object
# dtypes: float64(2), object(5)
# memory usage: 945.5+ MB

# %%
data_df.describe()
# Out:
#            Position       Streams
# count  1.554554e+07  1.554554e+07
# mean   9.673980e+01  5.655417e+04
# std    5.758853e+01  2.105495e+05
# min    1.000000e+00  1.001000e+03
# 25%    4.700000e+01  3.672000e+03
# 50%    9.500000e+01  1.003300e+04
# 75%    1.460000e+02  3.571700e+04
# max    2.000000e+02  1.722324e+07

# %%
data_df_cleaned = data_df.dropna()
data_df_cleaned.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
# Clearing unused memory
data_df = None

# %%
data_df_cleaned['region'].unique()
# Out:
# array(['global', 'ar', 'at', 'au', 'be', 'bg', 'bo', 'br', 'ca', 'ch',
#        'cl', 'co', 'cr', 'cz', 'de', 'dk', 'do', 'ec', 'ee', 'es', 'fi',
#        'fr', 'gb', 'gr', 'gt', 'hk', 'hn', 'hu', 'id', 'ie', 'is', 'it',
#        'jp', 'lt', 'lu', 'lv', 'mx', 'my', 'ni', 'nl', 'no', 'nz', 'pa',
#        'pe', 'ph', 'pl', 'pt', 'py', 'se', 'sg', 'sk', 'sv', 'tr', 'tw',
#        'us', 'uy', 'th', 'il', 'ro', 'vn'], dtype=object)

# %% [markdown]
# Now we will determine the regions with the most number of streams. These will be used to understand how the global trends in music are observed.

# %%
# Display top 20 regions with the highest total streams between 2017 and 2021
data_df_cleaned.groupby(["region"]).sum().sort_values(by="Streams", ascending=False).head(20)
# Out:
#           Position       Streams
# region
# global  29867706.0  3.506753e+11
# us      29907277.0  1.171383e+11
# br      29882152.0  4.060851e+10
# mx      29882225.0  3.529269e+10
# de      29809477.0  3.293648e+10
# gb      29888090.0  3.032301e+10
# es      29866158.0  2.098100e+10
# it      29847149.0  1.991240e+10
# fr      29907952.0  1.900275e+10
# au      29908230.0  1.643684e+10
# ca      29807909.0  1.570858e+10
# nl      29887043.0  1.564983e+10
# ph      29888235.0  1.509715e+10
# ar      29888075.0  1.462407e+10
# cl      29907816.0  1.356761e+10
# se      29888095.0  1.244967e+10
# id      29908444.0  1.149708e+10
# tr      29908526.0  8.888083e+09
# no      29867196.0  7.336934e+09
# pe      29867911.0  6.265531e+09

# %%
len(['global', 'ar', 'at', 'au', 'be', 'bg', 'bo', 'br', 'ca', 'ch',
       'cl', 'co', 'cr', 'cz', 'de', 'dk', 'do', 'ec', 'ee', 'es', 'fi',
       'fr', 'gb', 'gr', 'gt', 'hk', 'hn', 'hu', 'id', 'ie', 'is', 'it',
       'jp', 'lt', 'lu', 'lv', 'mx', 'my', 'ni', 'nl', 'no', 'nz', 'pa',
       'pe', 'ph', 'pl', 'pt', 'py', 'se', 'sg', 'sk', 'sv', 'tr', 'tw',
       'us', 'uy', 'th', 'il', 'ro', 'vn'])
# Out:
# 60

# %% [markdown]
# The following regions will be considered for the analysis:
# - Global (`global`)
# - United States (`us`)
# - Brazil (`br`)
# - Germany (`de`)
# - UK (`gb`)
# - Spain (`es`)
# - Canada (`ca`)
#
# Hence, data about all other regions will be removed.

# %%
data_df_cleaned[data_df_cleaned["region"] == "id"].head()
# Out:
#       Position            Track Name            Artist  Streams        date  \
# 4902       1.0                Closer  The Chainsmokers  45330.0  2017-01-01
# 4903       2.0  Say You Won't Let Go      James Arthur  40815.0  2017-01-01
# 4904       3.0           All We Know  The Chainsmokers  39557.0  2017-01-01
# 4905       4.0       Let Me Love You          DJ Snake  35205.0  2017-01-01
# 4906       5.0      Don't Wanna Know          Maroon 5  34084.0  2017-01-01
#
#      region              spotify_id
# 4902     id  7BKLCZ1jbUBVqRi2FVlTVw
# 4903     id  5uCax9HTNlzGybIStD3vDh
# 4904     id  2rizacJSyD9S1IQUxUxnsK
# 4905     id  4pdPtRcBmOSQDlJ3Fk945m
# 4906     id  5MFzQMkrl1FOOng9tq6R9r

# %%
regions = {"global": "global",
           "united states": "us",
           "brazil": "br",
           "germany": "de",
           "united kingdom": "gb",
           "spain": "es",
           "canada": "ca"
           }

# %%
df = data_df_cleaned[data_df_cleaned["region"].isin(regions.values())].copy()
df_cleaned = data_df_cleaned[data_df_cleaned["region"].isin(regions.values())].copy()
df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
data_df_cleaned = None

# %%
df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d")
df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams       date  region              spotify_id
# 0  3135625.0 2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0 2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0 2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0 2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0 2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
df.set_index(["date", "Position"], inplace=True)
df.head()
# Out:
#                                                   Track Name  \
# date       Position
# 2017-01-01 1.0                                       Starboy
#            2.0                                        Closer
#            3.0                               Let Me Love You
#            4.0       Rockabye (feat. Sean Paul & Anne-Marie)
#            5.0                                     One Dance
#
#                                Artist    Streams  region  \
# date       Position
# 2017-01-01 1.0             The Weeknd  3135625.0  global
#            2.0       The Chainsmokers  3015525.0  global
#            3.0               DJ Snake  2545384.0  global
#            4.0           Clean Bandit  2356604.0  global
#            5.0                  Drake  2259887.0  global
#
#                                  spotify_id
# date       Position
# 2017-01-01 1.0       5aAx2yezTd8zXrkmtKl66Z
#            2.0       7BKLCZ1jbUBVqRi2FVlTVw
#            3.0       4pdPtRcBmOSQDlJ3Fk945m
#            4.0       5knuzwU65gJK7IF5yJsuaW
#            5.0       1xznGGDReH1oQq0xzbwXa3

# %%
df.groupby(["Track Name", "date"]).sum()
# Out:
#                              Streams
# Track Name     date
# !              2019-08-09  2202702.0
#                2019-08-10  1188671.0
#                2019-08-11   363833.0
#                2019-08-12   349870.0
#                2019-08-13   297367.0
# ...                              ...
# 美女と野獣          2017-06-05    47780.0
#                2017-06-06    35973.0
# 蓝 - Cuéntamelo 2019-11-10    27517.0
#                2019-11-24    29534.0
# 說好不哭           2019-09-17    33493.0
#
# [1130803 rows x 1 columns]

# %%
df[df['region'] == "global"].groupby(["Artist"]).mean().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                      Streams
# Artist
# Olivia Rodrigo  3.296031e+06
# Tones And I     2.923192e+06
# SAINt JHN       2.673830e+06
# Wham!           2.558298e+06
# Internet Money  2.537534e+06
# Jawsh 685       2.455353e+06
# Mariah Carey    2.407342e+06
# 24kGoldn        2.348576e+06
# Powfu           2.322816e+06
# Bobby Helms     2.215141e+06
# Joel Corry      2.162781e+06
# Roddy Ricch     2.105746e+06
# Arizona Zervas  2.031774e+06
# Brenda Lee      2.013937e+06
# Trevor Daniel   1.990097e+06
# Tate McRae      1.983616e+06
# CJ              1.974629e+06
# THE SCOTTS      1.962331e+06
# Andy Williams   1.889429e+06
# BENEE           1.886778e+06

# %%
df.groupby(["Track Name", "Artist"]).sum().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                                                                     Streams
# Track Name                                    Artist
# Shape of You                                  Ed Sheeran       3.624923e+09
# Dance Monkey                                  Tones And I      2.804261e+09
# Blinding Lights                               The Weeknd       2.687621e+09
# Sunflower - Spider-Man: Into the Spider-Verse Post Malone      2.685540e+09
# Someone You Loved                             Lewis Capaldi    2.424276e+09
# Lucid Dreams                                  Juice WRLD       2.411695e+09
# bad guy                                       Billie Eilish    2.389620e+09
# Señorita                                      Shawn Mendes     2.284298e+09
# God's Plan                                    Drake            2.267490e+09
# SAD!                                          XXXTENTACION     2.235023e+09
# Believer                                      Imagine Dragons  2.148732e+09
# SICKO MODE                                    Travis Scott     2.082193e+09
# Perfect                                       Ed Sheeran       2.002734e+09
# Better Now                                    Post Malone      1.925164e+09
# Jocelyn Flores                                XXXTENTACION     1.909530e+09
# Happier                                       Marshmello       1.893711e+09
# 7 rings                                       Ariana Grande    1.884139e+09
# Circles                                       Post Malone      1.882313e+09
# Shallow                                       Lady Gaga        1.848654e+09
# Don't Start Now                               Dua Lipa         1.846095e+09

# %%
df['Artist'].value_counts()
# Out:
# Post Malone          47302
# Ed Sheeran           42122
# Drake                36578
# Billie Eilish        27524
# XXXTENTACION         27099
#                      ...
# Phats & Small            1
# Lazy Lizzard Gang        1
# Nu51                     1
# Llane                    1
# Lea Michele              1
# Name: Artist, Length: 3624, dtype: int64

# %%
# level_values = df["Track Name"].unique()
level_values = df.index.get_level_values
result = (df.groupby([level_values(i) for i in [0,1]]
                     +[pd.Grouper(freq='1y', level="date")]).sum())
result
# Out:
#                                   Streams
# date       Position date
# 2017-01-01 1.0      2017-12-31  5949703.0
#            2.0      2017-12-31  5160844.0
#            3.0      2017-12-31  4474651.0
#            4.0      2017-12-31  4166103.0
#            5.0      2017-12-31  3911050.0
# ...                                   ...
# 2021-01-30 196.0    2021-12-31  1234281.0
#            197.0    2021-12-31  1232348.0
#            198.0    2021-12-31  1228851.0
#            199.0    2021-12-31  1223439.0
#            200.0    2021-12-31  1222065.0
#
# [297600 rows x 1 columns]

# %%
result = (df.groupby("Track Name").mean()).sort_values(by="Streams", ascending=False).head(10)
result
# Out:
#                          Streams
# Track Name
# drivers license     2.299412e+06
# DÁKITI              1.454246e+06
# I'm the One         1.267468e+06
# LA NOCHE DE ANOCHE  1.230889e+06
# Allenamento #4      1.227269e+06
# MEVTR               1.216093e+06
# BICHOTA             1.180652e+06
# Celsius             1.168772e+06
# Don’t Matter To Me  1.153293e+06
# Hawái               1.092024e+06

# %%
df
# Out:
#                                                   Track Name  \
# date       Position
# 2017-01-01 1.0                                       Starboy
#            2.0                                        Closer
#            3.0                               Let Me Love You
#            4.0       Rockabye (feat. Sean Paul & Anne-Marie)
#            5.0                                     One Dance
# ...                                                      ...
# 2021-01-30 196.0                           Take Me To Church
#            197.0                                 Mr Loverman
#            198.0                                I Fall Apart
#            199.0                                  Kacey Talk
#            200.0                                         F.N
#
#                                          Artist    Streams  region  \
# date       Position
# 2017-01-01 1.0                       The Weeknd  3135625.0  global
#            2.0                 The Chainsmokers  3015525.0  global
#            3.0                         DJ Snake  2545384.0  global
#            4.0                     Clean Bandit  2356604.0  global
#            5.0                            Drake  2259887.0  global
# ...                                         ...        ...     ...
# 2021-01-30 196.0                         Hozier   216177.0      us
#            197.0               Ricky Montgomery   216126.0      us
#            198.0                    Post Malone   215343.0      us
#            199.0     YoungBoy Never Broke Again   215179.0      us
#            200.0                       Lil Tjay   215054.0      us
#
#                                  spotify_id
# date       Position
# 2017-01-01 1.0       5aAx2yezTd8zXrkmtKl66Z
#            2.0       7BKLCZ1jbUBVqRi2FVlTVw
#            3.0       4pdPtRcBmOSQDlJ3Fk945m
#            4.0       5knuzwU65gJK7IF5yJsuaW
#            5.0       1xznGGDReH1oQq0xzbwXa3
# ...                                     ...
# 2021-01-30 196.0     3dYD57lRAUcMHufyqn9GcI
#            197.0     2IVsRhKrx8hlQBOWy4qebo
#            198.0     75ZvA4QfFiZvzhj2xkaWAh
#            199.0     1SF8piqsZWn86DajVKih8F
#            200.0     0RLLvYBopDwooCyvnTwgYu
#
# [2079842 rows x 5 columns]

# %%
kaggle_df = pd.read_csv("data/kaggle_spotify_data.csv")
kaggle_df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920

# %%
kaggle_df.set_index("id").head()
# Out:
#                         acousticness                    artists  danceability  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI      0.991000            ['Mamie Smith']         0.598
# 0hbkKFIJm7Z05H8Zl9w30f      0.643000  ["Screamin' Jay Hawkins"]         0.852
# 11m7laMUgmOKqI3oYzuhne      0.993000            ['Mamie Smith']         0.647
# 19Lc5SfJJ5O1oaxY0fpwfh      0.000173        ['Oscar Velazquez']         0.730
# 2hJjbsLCytGsnAHfdsLejp      0.295000                   ['Mixe']         0.704
#
#                         duration_ms  energy  explicit  instrumentalness  key  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI       168333   0.224         0          0.000522    5
# 0hbkKFIJm7Z05H8Zl9w30f       150200   0.517         0          0.026400    5
# 11m7laMUgmOKqI3oYzuhne       163827   0.186         0          0.000018    0
# 19Lc5SfJJ5O1oaxY0fpwfh       422087   0.798         0          0.801000    2
# 2hJjbsLCytGsnAHfdsLejp       165224   0.707         1          0.000246   10
#
#                         liveness  loudness  mode  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI    0.3790   -12.628     0
# 0hbkKFIJm7Z05H8Zl9w30f    0.0809    -7.261     0
# 11m7laMUgmOKqI3oYzuhne    0.5190   -12.098     1
# 19Lc5SfJJ5O1oaxY0fpwfh    0.1280    -7.311     1
# 2hJjbsLCytGsnAHfdsLejp    0.4020    -6.036     0
#
#                                                                      name  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI                           Keep A Song In Your Soul
# 0hbkKFIJm7Z05H8Zl9w30f                               I Put A Spell On You
# 11m7laMUgmOKqI3oYzuhne                                       Golfing Papa
# 19Lc5SfJJ5O1oaxY0fpwfh  True House Music - Xavier Santos & Carlos Gomi...
# 2hJjbsLCytGsnAHfdsLejp                                          Xuniverxe
#
#                         popularity release_date  speechiness    tempo  \
# id
# 0cS0A1fUEUd1EW3FcF8AEI          12         1920       0.0936  149.976
# 0hbkKFIJm7Z05H8Zl9w30f           7   1920-01-05       0.0534   86.889
# 11m7laMUgmOKqI3oYzuhne           4         1920       0.1740   97.600
# 19Lc5SfJJ5O1oaxY0fpwfh          17   1920-01-01       0.0425  127.997
# 2hJjbsLCytGsnAHfdsLejp           2   1920-10-01       0.0768  122.076
#
#                         valence  year
# id
# 0cS0A1fUEUd1EW3FcF8AEI   0.6340  1920
# 0hbkKFIJm7Z05H8Zl9w30f   0.9500  1920
# 11m7laMUgmOKqI3oYzuhne   0.6890  1920
# 19Lc5SfJJ5O1oaxY0fpwfh   0.0422  1920
# 2hJjbsLCytGsnAHfdsLejp   0.2990  1920

# %%
df_cleaned.set_index("spotify_id").head()
# Out:
#                         Position                               Track Name  \
# spotify_id
# 5aAx2yezTd8zXrkmtKl66Z       1.0                                  Starboy
# 7BKLCZ1jbUBVqRi2FVlTVw       2.0                                   Closer
# 4pdPtRcBmOSQDlJ3Fk945m       3.0                          Let Me Love You
# 5knuzwU65gJK7IF5yJsuaW       4.0  Rockabye (feat. Sean Paul & Anne-Marie)
# 1xznGGDReH1oQq0xzbwXa3       5.0                                One Dance
#
#                                   Artist    Streams        date  region
# spotify_id
# 5aAx2yezTd8zXrkmtKl66Z        The Weeknd  3135625.0  2017-01-01  global
# 7BKLCZ1jbUBVqRi2FVlTVw  The Chainsmokers  3015525.0  2017-01-01  global
# 4pdPtRcBmOSQDlJ3Fk945m          DJ Snake  2545384.0  2017-01-01  global
# 5knuzwU65gJK7IF5yJsuaW      Clean Bandit  2356604.0  2017-01-01  global
# 1xznGGDReH1oQq0xzbwXa3             Drake  2259887.0  2017-01-01  global

# %%
id_set1 = set(df_cleaned["spotify_id"])
id_set2 = set(kaggle_df["id"])

len(id_set1), len(id_set2)
# Out:
# (22750, 172230)

# %%
len(id_set1.intersection(id_set2))
# Out:
# 3350

# %%
common_df = df_cleaned[df_cleaned["spotify_id"].isin(id_set1.intersection(id_set2))].set_index("spotify_id")
common_df.head()
# Out:
#                         Position                               Track Name  \
# spotify_id
# 7BKLCZ1jbUBVqRi2FVlTVw       2.0                                   Closer
# 5knuzwU65gJK7IF5yJsuaW       4.0  Rockabye (feat. Sean Paul & Anne-Marie)
# 343YBumqHu19cGoGARUTsd       6.0                                Fake Love
# 6b8Be6ljOzmkOmFslEb23P       7.0                                24K Magic
# 6fujklziTHa8uoM5OQSfIo       9.0                            Black Beatles
#
#                                   Artist    Streams        date  region
# spotify_id
# 7BKLCZ1jbUBVqRi2FVlTVw  The Chainsmokers  3015525.0  2017-01-01  global
# 5knuzwU65gJK7IF5yJsuaW      Clean Bandit  2356604.0  2017-01-01  global
# 343YBumqHu19cGoGARUTsd             Drake  2137437.0  2017-01-01  global
# 6b8Be6ljOzmkOmFslEb23P        Bruno Mars  2111599.0  2017-01-01  global
# 6fujklziTHa8uoM5OQSfIo      Rae Sremmurd  2075732.0  2017-01-01  global

# %%
common_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899721 entries, 7BKLCZ1jbUBVqRi2FVlTVw to 0RLLvYBopDwooCyvnTwgYu
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Position    899721 non-null  float64
#  1   Track Name  899721 non-null  object
#  2   Artist      899721 non-null  object
#  3   Streams     899721 non-null  float64
#  4   date        899721 non-null  object
#  5   region      899721 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 48.1+ MB

# %%
common_df.region.unique()
# Out:
# array(['global', 'br', 'ca', 'de', 'es', 'gb', 'us'], dtype=object)

# %%
common_df[common_df['region'] == "global"].groupby(["Artist"]).mean().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                    Position       Streams
# Artist
# Olivia Rodrigo   112.297619  3.296031e+06
# Internet Money    36.978261  2.765625e+06
# Jawsh 685         32.612069  2.730367e+06
# DJ Snake          35.774086  2.625365e+06
# Wham!             43.711957  2.558298e+06
# Mariah Carey      64.721831  2.424230e+06
# Brenda Lee        42.972727  2.383810e+06
# Paul McCartney    44.571429  2.361135e+06
# 24kGoldn          68.571788  2.348576e+06
# Powfu             35.334286  2.322816e+06
# Bobby Helms       44.730435  2.275902e+06
# Joel Corry        28.935323  2.162781e+06
# CJ                32.458824  2.138472e+06
# Justin Bieber     49.153207  2.137946e+06
# Lunay             23.941176  2.135512e+06
# Roddy Ricch       61.114063  2.118289e+06
# SAINt JHN         30.202381  2.077290e+06
# Black Eyed Peas   41.197581  2.042655e+06
# KAROL G           51.554667  2.026342e+06
# Arizona Zervas    69.401691  2.017153e+06

# %%
df[df['region'] == "global"].groupby(["Artist"]).mean().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                      Streams
# Artist
# Olivia Rodrigo  3.296031e+06
# Tones And I     2.923192e+06
# SAINt JHN       2.673830e+06
# Wham!           2.558298e+06
# Internet Money  2.537534e+06
# Jawsh 685       2.455353e+06
# Mariah Carey    2.407342e+06
# 24kGoldn        2.348576e+06
# Powfu           2.322816e+06
# Bobby Helms     2.215141e+06
# Joel Corry      2.162781e+06
# Roddy Ricch     2.105746e+06
# Arizona Zervas  2.031774e+06
# Brenda Lee      2.013937e+06
# Trevor Daniel   1.990097e+06
# Tate McRae      1.983616e+06
# CJ              1.974629e+06
# THE SCOTTS      1.962331e+06
# Andy Williams   1.889429e+06
# BENEE           1.886778e+06

# %%
common_df.groupby(["Track Name", "Artist"]).sum().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                                                               Position  \
# Track Name                                    Artist
# Shape of You                                  Ed Sheeran      589880.0
# Someone You Loved                             Lewis Capaldi   292516.0
# bad guy                                       Billie Eilish   265332.0
# Señorita                                      Shawn Mendes    233595.0
# Sunflower - Spider-Man: Into the Spider-Verse Post Malone     214717.0
# SAD!                                          XXXTENTACION    454244.0
# SICKO MODE                                    Travis Scott    327754.0
# Perfect                                       Ed Sheeran      632648.0
# Better Now                                    Post Malone     337251.0
# Jocelyn Flores                                XXXTENTACION    545321.0
# Happier                                       Marshmello      349394.0
# Don't Start Now                               Dua Lipa        154599.0
# Shallow                                       Lady Gaga       419299.0
# goosebumps                                    Travis Scott    608075.0
# Say You Won't Let Go                          James Arthur    705391.0
# The Box                                       Roddy Ricch     124346.0
# Circles                                       Post Malone     159509.0
# HUMBLE.                                       Kendrick Lamar  355015.0
# I Don't Care (with Justin Bieber)             Ed Sheeran      244116.0
# Congratulations                               Post Malone     466686.0
#
#                                                                    Streams
# Track Name                                    Artist
# Shape of You                                  Ed Sheeran      3.624923e+09
# Someone You Loved                             Lewis Capaldi   2.424276e+09
# bad guy                                       Billie Eilish   2.389620e+09
# Señorita                                      Shawn Mendes    2.284298e+09
# Sunflower - Spider-Man: Into the Spider-Verse Post Malone     2.266287e+09
# SAD!                                          XXXTENTACION    2.178097e+09
# SICKO MODE                                    Travis Scott    2.082193e+09
# Perfect                                       Ed Sheeran      2.002734e+09
# Better Now                                    Post Malone     1.925164e+09
# Jocelyn Flores                                XXXTENTACION    1.909530e+09
# Happier                                       Marshmello      1.893711e+09
# Don't Start Now                               Dua Lipa        1.846095e+09
# Shallow                                       Lady Gaga       1.836630e+09
# goosebumps                                    Travis Scott    1.826823e+09
# Say You Won't Let Go                          James Arthur    1.800134e+09
# The Box                                       Roddy Ricch     1.776338e+09
# Circles                                       Post Malone     1.738930e+09
# HUMBLE.                                       Kendrick Lamar  1.691318e+09
# I Don't Care (with Justin Bieber)             Ed Sheeran      1.686214e+09
# Congratulations                               Post Malone     1.677447e+09

# %%
df.groupby(["Track Name", "Artist"]).sum().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                                                                     Streams
# Track Name                                    Artist
# Shape of You                                  Ed Sheeran       3.624923e+09
# Dance Monkey                                  Tones And I      2.804261e+09
# Blinding Lights                               The Weeknd       2.687621e+09
# Sunflower - Spider-Man: Into the Spider-Verse Post Malone      2.685540e+09
# Someone You Loved                             Lewis Capaldi    2.424276e+09
# Lucid Dreams                                  Juice WRLD       2.411695e+09
# bad guy                                       Billie Eilish    2.389620e+09
# Señorita                                      Shawn Mendes     2.284298e+09
# God's Plan                                    Drake            2.267490e+09
# SAD!                                          XXXTENTACION     2.235023e+09
# Believer                                      Imagine Dragons  2.148732e+09
# SICKO MODE                                    Travis Scott     2.082193e+09
# Perfect                                       Ed Sheeran       2.002734e+09
# Better Now                                    Post Malone      1.925164e+09
# Jocelyn Flores                                XXXTENTACION     1.909530e+09
# Happier                                       Marshmello       1.893711e+09
# 7 rings                                       Ariana Grande    1.884139e+09
# Circles                                       Post Malone      1.882313e+09
# Shallow                                       Lady Gaga        1.848654e+09
# Don't Start Now                               Dua Lipa         1.846095e+09

# %%
df.groupby(["Track Name", "Artist"]).sum().sort_values(by="Streams", ascending=False).head(20)
# Out:
#                                                                     Streams
# Track Name                                    Artist
# Shape of You                                  Ed Sheeran       3.624923e+09
# Dance Monkey                                  Tones And I      2.804261e+09
# Blinding Lights                               The Weeknd       2.687621e+09
# Sunflower - Spider-Man: Into the Spider-Verse Post Malone      2.685540e+09
# Someone You Loved                             Lewis Capaldi    2.424276e+09
# Lucid Dreams                                  Juice WRLD       2.411695e+09
# bad guy                                       Billie Eilish    2.389620e+09
# Señorita                                      Shawn Mendes     2.284298e+09
# God's Plan                                    Drake            2.267490e+09
# SAD!                                          XXXTENTACION     2.235023e+09
# Believer                                      Imagine Dragons  2.148732e+09
# SICKO MODE                                    Travis Scott     2.082193e+09
# Perfect                                       Ed Sheeran       2.002734e+09
# Better Now                                    Post Malone      1.925164e+09
# Jocelyn Flores                                XXXTENTACION     1.909530e+09
# Happier                                       Marshmello       1.893711e+09
# 7 rings                                       Ariana Grande    1.884139e+09
# Circles                                       Post Malone      1.882313e+09
# Shallow                                       Lady Gaga        1.848654e+09
# Don't Start Now                               Dua Lipa         1.846095e+09

# %%
common_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899721 entries, 7BKLCZ1jbUBVqRi2FVlTVw to 0RLLvYBopDwooCyvnTwgYu
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Position    899721 non-null  float64
#  1   Track Name  899721 non-null  object
#  2   Artist      899721 non-null  object
#  3   Streams     899721 non-null  float64
#  4   date        899721 non-null  object
#  5   region      899721 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 68.1+ MB

# %%
kaggle_df[kaggle_df["id"].isin(id_set1.intersection(id_set2))].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3357 entries, 3664 to 174351
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      3357 non-null   float64
#  1   artists           3357 non-null   object
#  2   danceability      3357 non-null   float64
#  3   duration_ms       3357 non-null   int64
#  4   energy            3357 non-null   float64
#  5   explicit          3357 non-null   int64
#  6   id                3357 non-null   object
#  7   instrumentalness  3357 non-null   float64
#  8   key               3357 non-null   int64
#  9   liveness          3357 non-null   float64
#  10  loudness          3357 non-null   float64
#  11  mode              3357 non-null   int64
#  12  name              3357 non-null   object
#  13  popularity        3357 non-null   int64
#  14  release_date      3357 non-null   object
#  15  speechiness       3357 non-null   float64
#  16  tempo             3357 non-null   float64
#  17  valence           3357 non-null   float64
#  18  year              3357 non-null   int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 524.5+ KB

# %%
len(common_df.groupby("Artist").sum())
# Out:
# 1046

# %%
len(common_df.index.unique())
# Out:
# 3350

# %%
pd.merge(common_df, kaggle_df.set_index("id"))
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-74-0a9c9ca9cc90> in <module>
# ----> 1 pd.merge(common_df, kaggle_df.set_index("id"))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     643             warnings.warn(msg, UserWarning)
#     644
# --> 645         self._validate_specification()
#     646
#     647         # note this function has side effects
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1212                 common_cols = self.left.columns.intersection(self.right.columns)
#    1213                 if len(common_cols) == 0:
# -> 1214                     raise MergeError(
#    1215                         "No common columns to perform merge on. "
#    1216                         f"Merge options: left_on={self.left_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
pd.concat([common_df.groupby("Track Name").sum(), kaggle_df.set_index("id")], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-04aa50ea685f> in <module>
# ----> 1 pd.concat([common_df.groupby("Track Name").sum(), kaggle_df.set_index("id")], axis=1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     285     )
#     286
# --> 287     return op.get_result()
#     288
#     289
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     500                 mgrs_indexers.append((obj._mgr, indexers))
#     501
# --> 502             new_data = concatenate_block_managers(
#     503                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy,
#     504             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      82         blocks.append(b)
#      83
# ---> 84     return BlockManager(blocks, axes)
#      85
#      86
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     147
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#     151         # Populate known_consolidate, blknos, and blklocs lazily
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     324         for block in self.blocks:
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#     328             raise AssertionError(
#
# ValueError: Shape of passed values is (177525, 20), indices imply (175366, 20)

# %%
df.groupby("date").sum().plot(figsize=(20,10));

# %%
df_cleaned.to_csv("data/selected_regions_top_200_daily.csv", index=False)
