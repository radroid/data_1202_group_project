# %% [markdown]
# # Extracting Audio Features of Songs
# In this notebook, we will use `Spotify's Web API` to scarpe the audio features of the songs we have selected from the top 200 songs.

# %%
import pandas as pd

from __future__ import print_function    # (at top of module)
from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import sys
import pathlib
import os
import csv
from tqdm import tqdm

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="7dbe272b9d9b44278d84430e76374e88",
                                                      client_secret="14e94037bec24a3680b9249332a3d129")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace = False

# %%
sp.audio_features("7BKLCZ1jbUBVqRi2FVlTVw")
# Out:
# [{'danceability': 0.748,
#   'energy': 0.524,
#   'key': 8,
#   'loudness': -5.599,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 95.01,
#   'type': 'audio_features',
#   'id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'uri': 'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BKLCZ1jbUBVqRi2FVlTVw',
#   'duration_ms': 244960,
#   'time_signature': 4}]

# %%
# Define location of the data
data_dir = '../data'
filename = 'selected_regions_top_200_daily.csv'
data_path = os.path.join(data_dir, filename)

if not pathlib.Path(data_path).exists():
    raise FileNotFoundError('No file found at the location defined.')

# %%
# Load the dataset
filepath = pathlib.Path(data_path)

if filepath.exists():
    data_df = pd.read_csv(filepath, parse_dates=True)
else:
    data_df = pd.DataFrame()

# View the first 5 rows    
data_df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
track_ids = data_df["spotify_id"].unique()
track_ids, len(track_ids)
# Out:
# (array(['5aAx2yezTd8zXrkmtKl66Z', '7BKLCZ1jbUBVqRi2FVlTVw',
#         '4pdPtRcBmOSQDlJ3Fk945m', ..., '7as7OL7cmgFZDADgVjQZjz',
#         '1lVwFdNhP5q2HQdHoKX30A', '3rnso1KNGrkXfqNTlBXdPH'], dtype=object),
#  22750)

# %% [markdown]
# ## Extract Audio Features
# In this section, the audio features of the tracks that have been in the top 200 are going to be extracted and saved to a CSV file named `spotify_top_tracks_audio_features.csv`.
#
# > **Approximate time required**: `1 hour` and `20 minutes`.<sup>*</sup>
#
# <sup>*</sup>The estimated times can be different based your computer's performance.

# %%
with open(os.path.join(data_dir, 'spotify_top_tracks_audio_features.csv'), 'w') as csvfile:
    fieldnames = list(sp.audio_features("7BKLCZ1jbUBVqRi2FVlTVw")[0].keys())
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for track_id in tqdm(track_ids, desc="Saving Audio Features"):
        data_dict = sp.audio_features(track_id)[0]
        if data_dict is not None:
            writer.writerow(data_dict)
# Out:
# Saving Audio Features: 100%|██████████| 22750/22750 [50:13<00:00,  7.55it/s]

# %%
track_dets = sp.track("7BKLCZ1jbUBVqRi2FVlTVw")

# %%
sp.artist(track_dets["artists"][0]["id"])["genres"]
# Out:
# ['dance pop', 'edm', 'electropop', 'pop', 'pop dance', 'tropical house']

# %%
track = sp.track("7BKLCZ1jbUBVqRi2FVlTVw")
pprint(track["album"]["release_date"])
# Out:
# '2016-07-29'

# %%
with open(os.path.join(data_dir, 'spotify_top_tracks_release_dates.csv'), 'w') as csvfile:
    fieldnames = ["id", "release_date"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for track_id in tqdm(track_ids, desc="Saving Release Dates"):
        data_dict = {
            "id": track_id,
            "release_date": sp.track(track_id)["album"]["release_date"]
        }
        writer.writerow(data_dict)
# Out:
# Saving Release Dates: 100%|██████████| 22750/22750 [51:14<00:00,  7.40it/s]

# %%
data_df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
track_dets = data_df.iloc[0]

# %%
track = network.get_track(track_dets["Artist"], track_dets["Track Name"])

# %%
track.get_url()
# Out:
# 'https://www.last.fm/music/the%2bweeknd/_/starboy'

# %%
data_dict = sp.search(q="year:2018", market="us", limit=50, type='artist')

# %%
data_dict["artists"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
for artist in data_dict["artists"]["items"]:
    print(artist["name"])
    track_dict = sp.search(q=f"year:2018 & artist:{artist['name']}", market="us", limit=50, type='track')
    pprint(track_dict)
    break
# Out:
# Drake
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2018+%26+artist%3ADrake&type=track&market=US&offset=0&limit=50',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#                                               'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                                               'id': '3TVXtAsR1Inumwj472S9r4',
#                                               'name': 'Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#                                  'href': 'https://api.spotify.com/v1/albums/1ATL5GLyefJaxhQzSPVrLX',
#                                  'id': '1ATL5GLyefJaxhQzSPVrLX',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273f907de96b9a4fbc04accc0d5',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02f907de96b9a4fbc04accc0d5',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851f907de96b9a4fbc04accc0d5',
#                                              'width': 64}],
#                                  'name': 'Scorpion',
#                                  'release_date': '2018-06-29',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 25,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1ATL5GLyefJaxhQzSPVrLX'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#                                     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                                     'id': '3TVXtAsR1Inumwj472S9r4',
#                                     'name': 'Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pbi8H08p95NUZ7m6ybxUV'},
#                                     'href': 'https://api.spotify.com/v1/artists/3pbi8H08p95NUZ7m6ybxUV',
#                                     'id': '3pbi8H08p95NUZ7m6ybxUV',
#                                     'name': 'Static Major',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3pbi8H08p95NUZ7m6ybxUV'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#                                     'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#                                     'id': '7c0XG5cIJTrrAgEC3ULPiq',
#                                     'name': 'Ty Dolla $ign',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
#                        'disc_number': 2,
#                        'duration_ms': 289560,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USCM51800213'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/3mvYQKm8h6M5K5h0nVPY9S'},
#                        'href': 'https://api.spotify.com/v1/tracks/3mvYQKm8h6M5K5h0nVPY9S',
#                        'id': '3mvYQKm8h6M5K5h0nVPY9S',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'After Dark (feat. Static Major & Ty Dolla '
#                                '$ign)',
#                        'popularity': 62,
#                        'preview_url': None,
#                        'track_number': 11,
#                        'type': 'track',
#                        'uri': 'spotify:track:3mvYQKm8h6M5K5h0nVPY9S'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4ViyfJUTW0IT4SCBLexf'},
#                                               'href': 'https://api.spotify.com/v1/artists/0p4ViyfJUTW0IT4SCBLexf',
#                                               'id': '0p4ViyfJUTW0IT4SCBLexf',
#                                               'name': 'Drakeo the Ruler',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0p4ViyfJUTW0IT4SCBLexf'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/70jG1gVE13hv2x8lxZKAZo'},
#                                  'href': 'https://api.spotify.com/v1/albums/70jG1gVE13hv2x8lxZKAZo',
#                                  'id': '70jG1gVE13hv2x8lxZKAZo',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27353d35099aec566a0ed3ec1c0',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0253d35099aec566a0ed3ec1c0',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485153d35099aec566a0ed3ec1c0',
#                                              'width': 64}],
#                                  'name': 'Flu Flamming (Remix) [feat. Lil '
#                                          'Yachty & Ohgeesy]',
#                                  'release_date': '2018-11-02',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:70jG1gVE13hv2x8lxZKAZo'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4ViyfJUTW0IT4SCBLexf'},
#                                     'href': 'https://api.spotify.com/v1/artists/0p4ViyfJUTW0IT4SCBLexf',
#                                     'id': '0p4ViyfJUTW0IT4SCBLexf',
#                                     'name': 'Drakeo the Ruler',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:0p4ViyfJUTW0IT4SCBLexf'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6icQOAFXDZKsumw3YXyusw'},
#                                     'href': 'https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw',
#                                     'id': '6icQOAFXDZKsumw3YXyusw',
#                                     'name': 'Lil Yachty',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6icQOAFXDZKsumw3YXyusw'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ppQEG71r7jVpI8RudzycF'},
#                                     'href': 'https://api.spotify.com/v1/artists/3ppQEG71r7jVpI8RudzycF',
#                                     'id': '3ppQEG71r7jVpI8RudzycF',
#                                     'name': 'OHGEESY',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3ppQEG71r7jVpI8RudzycF'}],
#                        'disc_number': 1,
#                        'duration_ms': 142733,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USUYG1225592'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0xGILaSgLAAHdZCtLTLOqB'},
#                        'href': 'https://api.spotify.com/v1/tracks/0xGILaSgLAAHdZCtLTLOqB',
#                        'id': '0xGILaSgLAAHdZCtLTLOqB',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Flu Flamming (Remix) (feat. Lil Yachty & '
#                                'Ohgeesy)',
#                        'popularity': 41,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/490b10f135193a76bf10d920bc82d43a712de03a?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:0xGILaSgLAAHdZCtLTLOqB'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                               'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                               'id': '29ijED2bnnprp2TciAK1aO',
#                                               'name': 'Drake White',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/48OUIyfozfhZCjbTLfmWCX'},
#                                  'href': 'https://api.spotify.com/v1/albums/48OUIyfozfhZCjbTLfmWCX',
#                                  'id': '48OUIyfozfhZCjbTLfmWCX',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731de166d1b25b208399fec206',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021de166d1b25b208399fec206',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511de166d1b25b208399fec206',
#                                              'width': 64}],
#                                  'name': 'Drake White and the Big Fire (Live)',
#                                  'release_date': '2018-12-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 4,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:48OUIyfozfhZCjbTLfmWCX'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                     'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                     'id': '29ijED2bnnprp2TciAK1aO',
#                                     'name': 'Drake White',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                        'disc_number': 1,
#                        'duration_ms': 295253,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'TCADZ1835633'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7HmS8eJdjfd5gUpckIzZvt'},
#                        'href': 'https://api.spotify.com/v1/tracks/7HmS8eJdjfd5gUpckIzZvt',
#                        'id': '7HmS8eJdjfd5gUpckIzZvt',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'The Coast Is Clear (Live)',
#                        'popularity': 40,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/1b6579d28803801e6fbe40698ae13323af274305?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:7HmS8eJdjfd5gUpckIzZvt'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2foAaJeadpPstoqTuDss5Y'},
#                                  'href': 'https://api.spotify.com/v1/albums/2foAaJeadpPstoqTuDss5Y',
#                                  'id': '2foAaJeadpPstoqTuDss5Y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27348211b35de1773773619907f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0248211b35de1773773619907f',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485148211b35de1773773619907f',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 184813,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710508'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6oIF4CygktMOqRkrwmGFa4'},
#                        'href': 'https://api.spotify.com/v1/tracks/6oIF4CygktMOqRkrwmGFa4',
#                        'id': '6oIF4CygktMOqRkrwmGFa4',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'I Remember',
#                        'popularity': 41,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/57213862b129279a068c1ea4deb687088415be31?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 8,
#                        'type': 'track',
#                        'uri': 'spotify:track:6oIF4CygktMOqRkrwmGFa4'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                               'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                               'id': '29ijED2bnnprp2TciAK1aO',
#                                               'name': 'Drake White',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/48OUIyfozfhZCjbTLfmWCX'},
#                                  'href': 'https://api.spotify.com/v1/albums/48OUIyfozfhZCjbTLfmWCX',
#                                  'id': '48OUIyfozfhZCjbTLfmWCX',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731de166d1b25b208399fec206',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021de166d1b25b208399fec206',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511de166d1b25b208399fec206',
#                                              'width': 64}],
#                                  'name': 'Drake White and the Big Fire (Live)',
#                                  'release_date': '2018-12-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 4,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:48OUIyfozfhZCjbTLfmWCX'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                     'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                     'id': '29ijED2bnnprp2TciAK1aO',
#                                     'name': 'Drake White',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                        'disc_number': 1,
#                        'duration_ms': 210069,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'TCADZ1835632'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/12tZ2e5CkUW5Oq0udNxXBl'},
#                        'href': 'https://api.spotify.com/v1/tracks/12tZ2e5CkUW5Oq0udNxXBl',
#                        'id': '12tZ2e5CkUW5Oq0udNxXBl',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'All Would Be Right with the World (Live)',
#                        'popularity': 30,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/08fd1aa569d9359b2ed337ae06853888bef531c1?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:12tZ2e5CkUW5Oq0udNxXBl'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#                                               'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                                               'id': '3TVXtAsR1Inumwj472S9r4',
#                                               'name': 'Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/42wvKYHFezpmDuAP43558f'},
#                                  'href': 'https://api.spotify.com/v1/albums/42wvKYHFezpmDuAP43558f',
#                                  'id': '42wvKYHFezpmDuAP43558f',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273c185e37be2a06b5c6f2dc704',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02c185e37be2a06b5c6f2dc704',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851c185e37be2a06b5c6f2dc704',
#                                              'width': 64}],
#                                  'name': 'Scorpion',
#                                  'release_date': '2018-06-29',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 25,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:42wvKYHFezpmDuAP43558f'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#                                     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#                                     'id': '3TVXtAsR1Inumwj472S9r4',
#                                     'name': 'Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pbi8H08p95NUZ7m6ybxUV'},
#                                     'href': 'https://api.spotify.com/v1/artists/3pbi8H08p95NUZ7m6ybxUV',
#                                     'id': '3pbi8H08p95NUZ7m6ybxUV',
#                                     'name': 'Static Major',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3pbi8H08p95NUZ7m6ybxUV'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#                                     'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#                                     'id': '7c0XG5cIJTrrAgEC3ULPiq',
#                                     'name': 'Ty Dolla $ign',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
#                        'disc_number': 2,
#                        'duration_ms': 289560,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USCM51800214'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/07yzjL0GV0eSLAHW5qUPq4'},
#                        'href': 'https://api.spotify.com/v1/tracks/07yzjL0GV0eSLAHW5qUPq4',
#                        'id': '07yzjL0GV0eSLAHW5qUPq4',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'After Dark (feat. Static Major & Ty Dolla '
#                                '$ign)',
#                        'popularity': 28,
#                        'preview_url': None,
#                        'track_number': 11,
#                        'type': 'track',
#                        'uri': 'spotify:track:07yzjL0GV0eSLAHW5qUPq4'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                               'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                               'id': '29ijED2bnnprp2TciAK1aO',
#                                               'name': 'Drake White',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/48OUIyfozfhZCjbTLfmWCX'},
#                                  'href': 'https://api.spotify.com/v1/albums/48OUIyfozfhZCjbTLfmWCX',
#                                  'id': '48OUIyfozfhZCjbTLfmWCX',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731de166d1b25b208399fec206',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021de166d1b25b208399fec206',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511de166d1b25b208399fec206',
#                                              'width': 64}],
#                                  'name': 'Drake White and the Big Fire (Live)',
#                                  'release_date': '2018-12-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 4,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:48OUIyfozfhZCjbTLfmWCX'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                     'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                     'id': '29ijED2bnnprp2TciAK1aO',
#                                     'name': 'Drake White',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                        'disc_number': 1,
#                        'duration_ms': 210496,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'TCADZ1835640'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1VDwZzjuXlr4dNSNXUKbu7'},
#                        'href': 'https://api.spotify.com/v1/tracks/1VDwZzjuXlr4dNSNXUKbu7',
#                        'id': '1VDwZzjuXlr4dNSNXUKbu7',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Raised Right (Live)',
#                        'popularity': 29,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/5b58d67aaee112142c65c9e8355ec46fd7b0ce14?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:1VDwZzjuXlr4dNSNXUKbu7'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2foAaJeadpPstoqTuDss5Y'},
#                                  'href': 'https://api.spotify.com/v1/albums/2foAaJeadpPstoqTuDss5Y',
#                                  'id': '2foAaJeadpPstoqTuDss5Y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27348211b35de1773773619907f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0248211b35de1773773619907f',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485148211b35de1773773619907f',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 111653,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710502'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6a0QOq4hrxGlt1xsOoQNmJ'},
#                        'href': 'https://api.spotify.com/v1/tracks/6a0QOq4hrxGlt1xsOoQNmJ',
#                        'id': '6a0QOq4hrxGlt1xsOoQNmJ',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Little Weaver Bird',
#                        'popularity': 33,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/8f8b4b2a413454fb3f6a94dca7ddb1e85af44087?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:6a0QOq4hrxGlt1xsOoQNmJ'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                               'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                               'id': '29ijED2bnnprp2TciAK1aO',
#                                               'name': 'Drake White',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/48OUIyfozfhZCjbTLfmWCX'},
#                                  'href': 'https://api.spotify.com/v1/albums/48OUIyfozfhZCjbTLfmWCX',
#                                  'id': '48OUIyfozfhZCjbTLfmWCX',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731de166d1b25b208399fec206',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021de166d1b25b208399fec206',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511de166d1b25b208399fec206',
#                                              'width': 64}],
#                                  'name': 'Drake White and the Big Fire (Live)',
#                                  'release_date': '2018-12-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 4,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:48OUIyfozfhZCjbTLfmWCX'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29ijED2bnnprp2TciAK1aO'},
#                                     'href': 'https://api.spotify.com/v1/artists/29ijED2bnnprp2TciAK1aO',
#                                     'id': '29ijED2bnnprp2TciAK1aO',
#                                     'name': 'Drake White',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:29ijED2bnnprp2TciAK1aO'}],
#                        'disc_number': 1,
#                        'duration_ms': 289920,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'TCADZ1835637'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/26Loh7V8QaxsjrGHKA11tE'},
#                        'href': 'https://api.spotify.com/v1/tracks/26Loh7V8QaxsjrGHKA11tE',
#                        'id': '26Loh7V8QaxsjrGHKA11tE',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'It Feels Good (Live)',
#                        'popularity': 28,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/53d113e0bc495b58932e159a8f1294d471213ca3?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:26Loh7V8QaxsjrGHKA11tE'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2foAaJeadpPstoqTuDss5Y'},
#                                  'href': 'https://api.spotify.com/v1/albums/2foAaJeadpPstoqTuDss5Y',
#                                  'id': '2foAaJeadpPstoqTuDss5Y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27348211b35de1773773619907f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0248211b35de1773773619907f',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485148211b35de1773773619907f',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 110653,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710501'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0J1ROlGl0sPDiCqARcEtKx'},
#                        'href': 'https://api.spotify.com/v1/tracks/0J1ROlGl0sPDiCqARcEtKx',
#                        'id': '0J1ROlGl0sPDiCqARcEtKx',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Happiness',
#                        'popularity': 27,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/dee910ad1c1fea4081b98abd044ba70ffa6c2f3e?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:0J1ROlGl0sPDiCqARcEtKx'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2foAaJeadpPstoqTuDss5Y'},
#                                  'href': 'https://api.spotify.com/v1/albums/2foAaJeadpPstoqTuDss5Y',
#                                  'id': '2foAaJeadpPstoqTuDss5Y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27348211b35de1773773619907f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0248211b35de1773773619907f',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485148211b35de1773773619907f',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 102040,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710517'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2KUDjX2WZ5ReW88OiBI448'},
#                        'href': 'https://api.spotify.com/v1/tracks/2KUDjX2WZ5ReW88OiBI448',
#                        'id': '2KUDjX2WZ5ReW88OiBI448',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Poor Mum',
#                        'popularity': 22,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/1a3880d2ccb35e534ed00ceef9d386a987167236?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 17,
#                        'type': 'track',
#                        'uri': 'spotify:track:2KUDjX2WZ5ReW88OiBI448'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2foAaJeadpPstoqTuDss5Y'},
#                                  'href': 'https://api.spotify.com/v1/albums/2foAaJeadpPstoqTuDss5Y',
#                                  'id': '2foAaJeadpPstoqTuDss5Y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27348211b35de1773773619907f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0248211b35de1773773619907f',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485148211b35de1773773619907f',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 124173,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710504'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/23v3AseYz42wv1DUZlybYO'},
#                        'href': 'https://api.spotify.com/v1/tracks/23v3AseYz42wv1DUZlybYO',
#                        'id': '23v3AseYz42wv1DUZlybYO',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': "Love Isn't a Right",
#                        'popularity': 21,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/304ddebb77a748bd84495e3ce1256ea8590e4966?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:23v3AseYz42wv1DUZlybYO'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2foAaJeadpPstoqTuDss5Y'},
#                                  'href': 'https://api.spotify.com/v1/albums/2foAaJeadpPstoqTuDss5Y',
#                                  'id': '2foAaJeadpPstoqTuDss5Y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27348211b35de1773773619907f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0248211b35de1773773619907f',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485148211b35de1773773619907f',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 78946,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710506'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/3wp8Ewtp3qD7Bry87QrVyt'},
#                        'href': 'https://api.spotify.com/v1/tracks/3wp8Ewtp3qD7Bry87QrVyt',
#                        'id': '3wp8Ewtp3qD7Bry87QrVyt',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'How Wild the Wind Blows',
#                        'popularity': 21,
# ...
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2foAaJeadpPstoqTuDss5Y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 132466,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710524'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2LGV3Pyi0Q6wDZBiYXZhMS'},
#                        'href': 'https://api.spotify.com/v1/tracks/2LGV3Pyi0Q6wDZBiYXZhMS',
#                        'id': '2LGV3Pyi0Q6wDZBiYXZhMS',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Oh to Be in England',
#                        'popularity': 14,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/41876dc018d18f21a0f71d7b0c3cfb37d6f848e2?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 24,
#                        'type': 'track',
#                        'uri': 'spotify:track:2LGV3Pyi0Q6wDZBiYXZhMS'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4ATntg38TlAvrYJMmJ73b8'},
#                                  'href': 'https://api.spotify.com/v1/albums/4ATntg38TlAvrYJMmJ73b8',
#                                  'id': '4ATntg38TlAvrYJMmJ73b8',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2734372c87c756f79af5aa57992',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e024372c87c756f79af5aa57992',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048514372c87c756f79af5aa57992',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4ATntg38TlAvrYJMmJ73b8'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 117080,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710510'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6MHgGzqVkQWme9BAdXR10e'},
#                        'href': 'https://api.spotify.com/v1/tracks/6MHgGzqVkQWme9BAdXR10e',
#                        'id': '6MHgGzqVkQWme9BAdXR10e',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Ballad',
#                        'popularity': 7,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/ad8644e36800ab7f2abb389fd8093c2813e004f8?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 10,
#                        'type': 'track',
#                        'uri': 'spotify:track:6MHgGzqVkQWme9BAdXR10e'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4ATntg38TlAvrYJMmJ73b8'},
#                                  'href': 'https://api.spotify.com/v1/albums/4ATntg38TlAvrYJMmJ73b8',
#                                  'id': '4ATntg38TlAvrYJMmJ73b8',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2734372c87c756f79af5aa57992',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e024372c87c756f79af5aa57992',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048514372c87c756f79af5aa57992',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4ATntg38TlAvrYJMmJ73b8'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 98733,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710518'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7lIZeCCKrD5OoHWOUw63yN'},
#                        'href': 'https://api.spotify.com/v1/tracks/7lIZeCCKrD5OoHWOUw63yN',
#                        'id': '7lIZeCCKrD5OoHWOUw63yN',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Do You Ever Remember?',
#                        'popularity': 6,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/21b8cb489b05f8d163fad22c5c65f370aec3784a?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 18,
#                        'type': 'track',
#                        'uri': 'spotify:track:7lIZeCCKrD5OoHWOUw63yN'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4ATntg38TlAvrYJMmJ73b8'},
#                                  'href': 'https://api.spotify.com/v1/albums/4ATntg38TlAvrYJMmJ73b8',
#                                  'id': '4ATntg38TlAvrYJMmJ73b8',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2734372c87c756f79af5aa57992',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e024372c87c756f79af5aa57992',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048514372c87c756f79af5aa57992',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4ATntg38TlAvrYJMmJ73b8'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 108093,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710521'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1XSibeeBqAE68SQCoxKYlJ'},
#                        'href': 'https://api.spotify.com/v1/tracks/1XSibeeBqAE68SQCoxKYlJ',
#                        'id': '1XSibeeBqAE68SQCoxKYlJ',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Some Other Spring',
#                        'popularity': 6,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/dea8af2e2a6bef1fd2a471a3b15ae96578ffd50c?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 21,
#                        'type': 'track',
#                        'uri': 'spotify:track:1XSibeeBqAE68SQCoxKYlJ'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                               'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                               'id': '1789Un2gEvELbBTnHoS9Rl',
#                                               'name': 'Molly Drake',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4ATntg38TlAvrYJMmJ73b8'},
#                                  'href': 'https://api.spotify.com/v1/albums/4ATntg38TlAvrYJMmJ73b8',
#                                  'id': '4ATntg38TlAvrYJMmJ73b8',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2734372c87c756f79af5aa57992',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e024372c87c756f79af5aa57992',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048514372c87c756f79af5aa57992',
#                                              'width': 64}],
#                                  'name': "The Tide's Magnificence: Songs and "
#                                          'Poems of Molly Drake',
#                                  'release_date': '2018-02-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 26,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4ATntg38TlAvrYJMmJ73b8'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1789Un2gEvELbBTnHoS9Rl'},
#                                     'href': 'https://api.spotify.com/v1/artists/1789Un2gEvELbBTnHoS9Rl',
#                                     'id': '1789Un2gEvELbBTnHoS9Rl',
#                                     'name': 'Molly Drake',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1789Un2gEvELbBTnHoS9Rl'}],
#                        'disc_number': 1,
#                        'duration_ms': 99666,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBBLD1710512'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/40St2SHQ5grtQT3MGCnNxF'},
#                        'href': 'https://api.spotify.com/v1/tracks/40St2SHQ5grtQT3MGCnNxF',
#                        'id': '40St2SHQ5grtQT3MGCnNxF',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Night Is My Friend',
#                        'popularity': 6,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/037050dc1639b426fdd2e78f13545217b055ac72?cid=7dbe272b9d9b44278d84430e76374e88',
#                        'track_number': 12,
#                        'type': 'track',
#                        'uri': 'spotify:track:40St2SHQ5grtQT3MGCnNxF'}],
#             'limit': 50,
#             'next': 'https://api.spotify.com/v1/search?query=year%3A2018+%26+artist%3ADrake&type=track&market=US&offset=50&limit=50',
#             'offset': 0,
#             'previous': None,
#             'total': 114}}

# %%
for track in track_dict["tracks"]["items"]:
    artists = [data["name"] for data in track["artists"]]
    print(artists)
    break
# Out:
# ['Drake', 'Static Major', 'Ty Dolla $ign']
