# %% [markdown]
# # Extracting Audio Features of Songs
# In this notebook, we will use `Spotify's Web API` to scarpe the audio features of the songs we have selected from the top 200 songs.

# %%
import pandas as pd

from __future__ import print_function
from pprint import pprint

try: 
    import spotipy
    from spotipy.oauth2 import SpotifyClientCredentials
except ModuleNotFoundError:
    print("Installing Spotipy library using `pip`.")
    # !pip install spotipy --quiet
    import spotipy
    from spotipy.oauth2 import SpotifyClientCredentials    

import json
import time
import sys
import pathlib
import os
import csv

try:
    from tqdm import tqdm
except ModuleNotFoundError:
    print("Installing tqdm library using `pip`.")
    # !pip install tqdm --quiet
    from tqdm import tqdm

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="7dbe272b9d9b44278d84430e76374e88",
                                                      client_secret="14e94037bec24a3680b9249332a3d129")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace = False

# %%
sp.audio_features("7BKLCZ1jbUBVqRi2FVlTVw")
# Out:
# [{'danceability': 0.748,
#   'energy': 0.524,
#   'key': 8,
#   'loudness': -5.599,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 95.01,
#   'type': 'audio_features',
#   'id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'uri': 'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BKLCZ1jbUBVqRi2FVlTVw',
#   'duration_ms': 244960,
#   'time_signature': 4}]

# %%
# Define location of the data
data_dir = '../data'
filename = 'selected_regions_top_200_daily.csv'
data_path = os.path.join(data_dir, filename)

if not pathlib.Path(data_path).exists():
    raise FileNotFoundError('No file found at the location defined.')

# %%
# Load the dataset
filepath = pathlib.Path(data_path)

if filepath.exists():
    data_df = pd.read_csv(filepath, parse_dates=True)
else:
    data_df = pd.DataFrame()

# View the first 5 rows    
data_df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
track_ids = data_df["spotify_id"].unique()
track_ids, len(track_ids)
# Out:
# (array(['5aAx2yezTd8zXrkmtKl66Z', '7BKLCZ1jbUBVqRi2FVlTVw',
#         '4pdPtRcBmOSQDlJ3Fk945m', ..., '7as7OL7cmgFZDADgVjQZjz',
#         '1lVwFdNhP5q2HQdHoKX30A', '3rnso1KNGrkXfqNTlBXdPH'], dtype=object),
#  22750)

# %% [markdown]
# ## Extract Audio Features
# In this section, the audio features of the tracks that have been in the top 200 are going to be extracted and saved to a CSV file named `spotify_top_tracks_audio_features.csv`.
#
# > **Approximate time required**: `1 hour` and `20 minutes`.<sup>*</sup>
#
# <sup>*</sup>The estimated times can be different based your computer's performance.
#
# ### Save Audio Features of Tracks
# In this section, the audio features of the tracks are downloaded.

# %%
with open(os.path.join(data_dir, 'spotify_top_tracks_audio_features.csv'), 'w') as csvfile:
    fieldnames = list(sp.audio_features("7BKLCZ1jbUBVqRi2FVlTVw")[0].keys())
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for track_id in tqdm(track_ids, desc="Saving Audio Features"):
        data_dict = sp.audio_features(track_id)[0]
        if data_dict is not None:
            writer.writerow(data_dict)
# Out:
# Saving Audio Features: 100%|██████████| 22750/22750 [50:13<00:00,  7.55it/s]

# %%
track_dets = sp.track("7BKLCZ1jbUBVqRi2FVlTVw")

# %%
sp.artist(track_dets["artists"][0]["id"])["genres"]
# Out:
# ['dance pop', 'edm', 'electropop', 'pop', 'pop dance', 'tropical house']

# %%
track = sp.track("7BKLCZ1jbUBVqRi2FVlTVw")
pprint(track["album"]["release_date"])
# Out:
# '2016-07-29'

# %% [markdown]
# ### Save Release Dates for All Tracks
# In this section, we get the information on the release date of the tracks and save it to a different CSV file.
#
# > **Approximate time required**: `1 hour` and `20 minutes`.<sup>*</sup>
#
# <sup>*</sup>The estimated times can be different based your computer's performance.

# %%
with open(os.path.join(data_dir, 'spotify_top_tracks_release_dates.csv'), 'w') as csvfile:
    fieldnames = ["id", "release_date"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for track_id in tqdm(track_ids, desc="Saving Release Dates"):
        data_dict = {
            "id": track_id,
            "release_date": sp.track(track_id)["album"]["release_date"]
        }
        writer.writerow(data_dict)
# Out:
# Saving Release Dates: 100%|██████████| 22750/22750 [51:14<00:00,  7.40it/s]

# %%
data_df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0       1.0                                  Starboy        The Weeknd
# 1       2.0                                   Closer  The Chainsmokers
# 2       3.0                          Let Me Love You          DJ Snake
# 3       4.0  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4       5.0                                One Dance             Drake
#
#      Streams        date  region              spotify_id
# 0  3135625.0  2017-01-01  global  5aAx2yezTd8zXrkmtKl66Z
# 1  3015525.0  2017-01-01  global  7BKLCZ1jbUBVqRi2FVlTVw
# 2  2545384.0  2017-01-01  global  4pdPtRcBmOSQDlJ3Fk945m
# 3  2356604.0  2017-01-01  global  5knuzwU65gJK7IF5yJsuaW
# 4  2259887.0  2017-01-01  global  1xznGGDReH1oQq0xzbwXa3

# %%
track_dets = data_df.iloc[0]

# %%
track = network.get_track(track_dets["Artist"], track_dets["Track Name"])

# %%
track.get_url()
# Out:
# 'https://www.last.fm/music/the%2bweeknd/_/starboy'

# %%
data_dict["artists"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
regions = {"global": "global",
           "united states": "us",
           "brazil": "br",
           "germany": "de",
           "united kingdom": "gb",
           "spain": "es",
           "canada": "ca"
           }

# %%
with open(os.path.join(data_dir, 'spotify_released_tracks_1920_to_2020.csv'), 'w') as csvfile:
    fieldnames = ["Track Name", "Artist", "artists", "spotify_id", "release_date", "region"]

    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    for year in range(1920,2021):
        album_dict = sp.search(q=f"year:{year}",
                          limit=50, type='album')
        for album in tqdm(album_dict["albums"]["items"], desc=f"Saving data for the year {year}"):
            album_artists = [data["name"] for data in album["artists"]]
            query = f"album:{album['name']}"
            track_dict = sp.search(q=query, limit=50)

            for track in track_dict["tracks"]["items"]:
                artists = [data["name"] for data in track["artists"]]
                writer.writerow(
                    {
                    "Track Name": track["name"],
                    "Artist": album_artists[0],
                    "artists": artists,
                    "spotify_id": track["id"],
                    "release_date": track["album"]["release_date"]
                }
                )
# Out:
# Saving data for the year 1920: 100%|██████████| 50/50 [00:09<00:00,  5.11it/s]
# Saving data for the year 1921: 100%|██████████| 50/50 [00:12<00:00,  3.87it/s]
# Saving data for the year 1922: 100%|██████████| 11/11 [00:02<00:00,  4.15it/s]
# Saving data for the year 1923: 100%|██████████| 17/17 [00:04<00:00,  4.20it/s]
# Saving data for the year 1924: 100%|██████████| 20/20 [00:04<00:00,  4.59it/s]
# Saving data for the year 1925: 100%|██████████| 20/20 [00:04<00:00,  4.23it/s]
# Saving data for the year 1926: 100%|██████████| 37/37 [00:08<00:00,  4.14it/s]
# Saving data for the year 1927: 100%|██████████| 50/50 [00:11<00:00,  4.34it/s]
# Saving data for the year 1928: 100%|██████████| 50/50 [00:11<00:00,  4.41it/s]
# Saving data for the year 1929: 100%|██████████| 50/50 [00:11<00:00,  4.51it/s]
# Saving data for the year 1930: 100%|██████████| 50/50 [00:13<00:00,  3.64it/s]
# Saving data for the year 1931: 100%|██████████| 50/50 [00:11<00:00,  4.44it/s]
# Saving data for the year 1932: 100%|██████████| 50/50 [00:11<00:00,  4.47it/s]
# Saving data for the year 1933: 100%|██████████| 45/45 [00:11<00:00,  4.04it/s]
# Saving data for the year 1934: 100%|██████████| 50/50 [00:12<00:00,  4.10it/s]
# Saving data for the year 1935: 0it [00:00, ?it/s]
# Saving data for the year 1936: 100%|██████████| 50/50 [00:10<00:00,  4.60it/s]
# Saving data for the year 1937: 100%|██████████| 50/50 [00:10<00:00,  4.63it/s]
# Saving data for the year 1938: 100%|██████████| 50/50 [00:10<00:00,  4.73it/s]
# Saving data for the year 1939: 100%|██████████| 50/50 [00:11<00:00,  4.53it/s]
# Saving data for the year 1940: 100%|██████████| 50/50 [00:10<00:00,  4.55it/s]
# Saving data for the year 1941: 100%|██████████| 50/50 [00:10<00:00,  4.63it/s]
# Saving data for the year 1942: 100%|██████████| 50/50 [00:10<00:00,  4.79it/s]
# Saving data for the year 1943: 100%|██████████| 50/50 [00:10<00:00,  4.86it/s]
# Saving data for the year 1944: 100%|██████████| 50/50 [00:11<00:00,  4.52it/s]
# Saving data for the year 1945: 100%|██████████| 50/50 [00:11<00:00,  4.17it/s]
# Saving data for the year 1946: 100%|██████████| 50/50 [00:11<00:00,  4.32it/s]
# Saving data for the year 1947: 100%|██████████| 50/50 [00:11<00:00,  4.48it/s]
# Saving data for the year 1948: 100%|██████████| 50/50 [00:10<00:00,  4.72it/s]
# Saving data for the year 1949: 100%|██████████| 50/50 [00:11<00:00,  4.31it/s]
# Saving data for the year 1950: 100%|██████████| 50/50 [00:11<00:00,  4.45it/s]
# Saving data for the year 1951: 100%|██████████| 50/50 [00:11<00:00,  4.41it/s]
# Saving data for the year 1952: 100%|██████████| 50/50 [00:11<00:00,  4.48it/s]
# Saving data for the year 1953: 100%|██████████| 50/50 [00:11<00:00,  4.35it/s]
# Saving data for the year 1954: 100%|██████████| 50/50 [00:10<00:00,  4.57it/s]
# Saving data for the year 1955: 100%|██████████| 50/50 [00:10<00:00,  4.59it/s]
# Saving data for the year 1956: 100%|██████████| 50/50 [00:10<00:00,  4.75it/s]
# Saving data for the year 1957: 100%|██████████| 50/50 [00:10<00:00,  4.64it/s]
# Saving data for the year 1958: 100%|██████████| 50/50 [00:10<00:00,  4.70it/s]
# Saving data for the year 1959: 100%|██████████| 50/50 [00:10<00:00,  4.55it/s]
# Saving data for the year 1960: 100%|██████████| 50/50 [00:10<00:00,  4.59it/s]
# Saving data for the year 1961: 100%|██████████| 50/50 [00:10<00:00,  4.77it/s]
# Saving data for the year 1962: 100%|██████████| 50/50 [00:11<00:00,  4.23it/s]
# Saving data for the year 1963: 100%|██████████| 50/50 [00:11<00:00,  4.40it/s]
# Saving data for the year 1964: 100%|██████████| 50/50 [00:10<00:00,  4.62it/s]
# Saving data for the year 1965: 100%|██████████| 50/50 [00:12<00:00,  4.07it/s]
# Saving data for the year 1966:  48%|████▊     | 24/50 [00:10<00:10,  2.37it/s]
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     448             raise
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     335         if isinstance(err, SocketTimeout):
# --> 336             raise ReadTimeoutError(
#     337                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-92-15d4e78110b8> in <module>
#      12             album_artists = [data["name"] for data in album["artists"]]
#      13             query = f"album:{album['name']}"
# ---> 14             track_dict = sp.search(q=query, limit=50)
#      15
#      16             for track in track_dict["tracks"]["items"]:
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     545                            from_token.
#     546         """
# --> 547         return self._get(
#     548             "search", q=q, limit=limit, offset=offset, type=type, market=market
#     549         )
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     238
#     239         try:
# --> 240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
#     242                 timeout=self.requests_timeout, **args
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/Documents/computer-science/data_analytics_durham/1202-Data_Analysis_Tools_Analytics/Assignments/data_1202_group_project/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)

# %%
df = pd.read_csv(os.path.join(data_dir, 'spotify_released_tracks_1920_to_2020.csv'))
df.head()
# Out:
#                      Track Name       Artist  \
# 0      Keep A Song In Your Soul  Mamie Smith
# 1  Don't You Advertise Your Man  Mamie Smith
# 2   Crazy Blues - 78rpm Version  Mamie Smith
# 3                  Golfing Papa  Mamie Smith
# 4             Mamie Smith Blues  Mamie Smith
#
#                              artists              spotify_id release_date  \
# 0                    ['Mamie Smith']  0cS0A1fUEUd1EW3FcF8AEI         1920
# 1                    ['Mamie Smith']  5DlCyqLyX2AOVDTjjkDZ8x         1920
# 2  ['Mamie Smith & Her Jazz Hounds']  3HnrHGLE9u2MjHtdobfWl9         1920
# 3                    ['Mamie Smith']  11m7laMUgmOKqI3oYzuhne         1920
# 4  ['Mamie Smith & Her Jazz Hounds']  5CMLMZ18hkm3QgDFzJdlTN         1920
#
#    region
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df[df.release_date == "1920"]
# Out:
#                                              Track Name               Artist  \
# 0                              Keep A Song In Your Soul          Mamie Smith
# 1                          Don't You Advertise Your Man          Mamie Smith
# 2                           Crazy Blues - 78rpm Version          Mamie Smith
# 3                                          Golfing Papa          Mamie Smith
# 4                                     Mamie Smith Blues          Mamie Smith
# 5                                 The Lure Of The South          Mamie Smith
# 6                                   The Wang Wang Blues          Mamie Smith
# 7                              A-Wearin' Away The Blues          Mamie Smith
# 8                                        Arkansas Blues          Mamie Smith
# 9                                          Wabash Blues          Mamie Smith
# 10                                        Frankie Blues          Mamie Smith
# 11                Kansas City Man Blues - 78rpm Version          Mamie Smith
# 12                                     Don't Care Blues          Mamie Smith
# 13                                      Down Home Blues          Mamie Smith
# 14                                     Mean Daddy Blues          Mamie Smith
# 15                                  Dem Knock-Out Blues          Mamie Smith
# 16                           "U" Need Some Lovin' Blues          Mamie Smith
# 17                          The Darktown Flappers' Ball          Mamie Smith
# 18    Miss Jenny's Ball (aka There'll Be No Freebies...          Mamie Smith
# 19                                  Do It Mr. So-And-So          Mamie Smith
# 20                                      My Sportin' Man          Mamie Smith
# 21    I Ain't Gonna Give Nobody None O' This Jelly Roll          Mamie Smith
# 22                              It's Right Here for You          Mamie Smith
# 23                                    That Da Da Strain          Mamie Smith
# 24                                             Mean Man          Mamie Smith
# 572                                 La Femme Aux Bijoux      Various Artists
# 573                               Ca N'vaut Pas L'amour      Various Artists
# 574                                   Le Tango De Manon      Various Artists
# 700                                     My Little Bimbo  South Shore Singers
# 702                        Baytân Mujtathth et taghtiya            ibn Arûsh
# 703                            Baytân Madîd et taghtiya            ibn Arûsh
# 704                            Mawwâl et taghtiya Sâhlî            ibn Arûsh
# 705            Mawwâl Irâq et qasîda malhûna miknâsiyya            ibn Arûsh
# 706                         Baytân et taghtiya Istihlâl            ibn Arûsh
# 707                Mawwâl et batâ'ihî al-Hijâz al-Kabîr            ibn Arûsh
# 708                           Baytân Mazmûm et taghtiya            ibn Arûsh
# 709          Baytân Ramal et batâ'ihî al-Hijâz al-Kabîr            ibn Arûsh
# 710           Baytân Majzû' al-Ramal et batâ'hî al-Mâya            ibn Arûsh
# 711                            Mawwâl Misrî et taghtiya            ibn Arûsh
# 712                              Insirâf quddâm al-Mâya            ibn Arûsh
# 713                                  “Dhikr ed-Drîsiyya            ibn Arûsh
# 714                         “Aytat ed-Dâr el-Beydâ, II"            ibn Arûsh
# 715                                Sanat shughl “Yâ jâr            ibn Arûsh
# 716                      Sanat shughl “Malîhu l-muhayyâ            ibn Arûsh
# 717                                     Tawshiyat Iblîs            ibn Arûsh
# 718                                         Mawwâl Sîkâ            ibn Arûsh
# 719                       “Dhikr bent Haniyya we-Haddûn            ibn Arûsh
# 720         Sana “Zidnî bi-farti l-hubbi fîka tahayyurâ            ibn Arûsh
# 721                          “Aytat ed-Dâr el-Beydâ, I"            ibn Arûsh
# 722                                    Qasîda mujûniyya            ibn Arûsh
# 723                   Sanat shughl “Ahdä nasîmu s-sabâh            ibn Arûsh
# 724                                  Qasîda tlimsâniyya            ibn Arûsh
# 825                              Descuernacabras (Live)     Gustavo Obligado
# 826                                   Sin Safari (Live)     Gustavo Obligado
# 827                                   Al Ornette (Live)     Gustavo Obligado
# 828                                  Ravel Ravel (Live)     Gustavo Obligado
# 829   Indios Cheroqui (Live) [feat. Ariel Flores & S...     Gustavo Obligado
# 830   Eurodance (Live) [feat. Ariel Flores & Sam Nacht]     Gustavo Obligado
# 1230                                      سبحان من ذكره        محمد الإدريسي
# 1365                                          Poppyland  South Shore Singers
#
#                                                 artists  \
# 0                                       ['Mamie Smith']
# 1                                       ['Mamie Smith']
# 2                     ['Mamie Smith & Her Jazz Hounds']
# 3                                       ['Mamie Smith']
# 4                     ['Mamie Smith & Her Jazz Hounds']
# 5                                       ['Mamie Smith']
# 6                     ['Mamie Smith & Her Jazz Hounds']
# 7                     ['Mamie Smith & Her Jazz Hounds']
# 8                     ['Mamie Smith & Her Jazz Hounds']
# 9                     ['Mamie Smith & Her Jazz Hounds']
# 10                    ['Mamie Smith & Her Jazz Hounds']
# 11                   ['Mamie Smith', 'The Harlem Trio']
# 12                    ['Mamie Smith & Her Jazz Hounds']
# 13                    ['Mamie Smith & Her Jazz Hounds']
# 14                    ['Mamie Smith & Her Jazz Hounds']
# 15                    ['Mamie Smith & Her Jazz Hounds']
# 16                    ['Mamie Smith & Her Jazz Hounds']
# 17                    ['Mamie Smith & Her Jazz Hounds']
# 18                                      ['Mamie Smith']
# 19                   ['Mamie Smith', 'Porter Grainger']
# 20                                      ['Mamie Smith']
# 21                    ['Mamie Smith & Her Jazz Hounds']
# 22                    ['Mamie Smith & Her Jazz Hounds']
# 23                    ['Mamie Smith & Her Jazz Hounds']
# 24                    ['Mamie Smith & Her Jazz Hounds']
# 572                                        ['Marcelly']
# 573                                   ['Esther Lekain']
# 574                                          ['Gorgel']
# 700                             ['South Shore Singers']
# 702                          ['Abd al-Rahmân Zuwaytin']
# 703                                ['Idrîs ibn Jallûn']
# 704                                     ['David Zaynû']
# 705                                       ['ibn Arûsh']
# 706                          ['Abd al-Rahmân Zuwaytin']
# 707                                     ['David Zaynû']
# 708                                  ['Azzûz ibn Nânî']
# 709                                ['Idrîs ibn Jallûn']
# 710                                ['Idrîs ibn Jallûn']
# 711                                  ['Azzûz ibn Nânî']
# 712                               ['Muhammad al-Brîhî']
# 713                            ['Shaykha bint Haniyya']
# 714                            ['Abd al-Qâdir Battîta']
# 715                                  ['Azzûz ibn Nânî']
# 716                                  ['Azzûz ibn Nânî']
# 717                                  ['Azzûz ibn Nânî']
# 718                                       ['ibn Arûsh']
# 719                            ['Shaykha bint Haniyya']
# 720                                ['Idrîs ibn Jallûn']
# 721                            ['Abd al-Qâdir Battîta']
# 722                                ['Idrîs ibn Jallûn']
# 723                                  ['Azzûz ibn Nânî']
# 724                                     ['David Zaynû']
# 825                                ['Gustavo Obligado']
# 826                                ['Gustavo Obligado']
# 827                                ['Gustavo Obligado']
# 828                                ['Gustavo Obligado']
# 829   ['Gustavo Obligado', 'Ariel Flores', 'Sam Nacht']
# 830   ['Gustavo Obligado', 'Ariel Flores', 'Sam Nacht']
# 1230                                  ['محمد الإدريسي']
# 1365                            ['South Shore Singers']
#
#                   spotify_id release_date  region
# 0     0cS0A1fUEUd1EW3FcF8AEI         1920     NaN
# 1     5DlCyqLyX2AOVDTjjkDZ8x         1920     NaN
# 2     3HnrHGLE9u2MjHtdobfWl9         1920     NaN
# 3     11m7laMUgmOKqI3oYzuhne         1920     NaN
# 4     5CMLMZ18hkm3QgDFzJdlTN         1920     NaN
# 5     5Dh1E4kXDwXwVfChsExG3G         1920     NaN
# 6     5SNmWjfuDJT9Vm9PZafQgr         1920     NaN
# 7     63A7QZjTgxw7F9N8wUyV9v         1920     NaN
# 8     02FzJbHtqElixxCmrpSCUa         1920     NaN
# 9     62kpKERs2EyhfJ6WKa2aDe         1920     NaN
# 10    1DfwOz5apF0w2d8hccSkhH         1920     NaN
# 11    0lqEx4vktZP1y9hnwfF27Y         1920     NaN
# 12    4RDT3ftT3V0IJVmW0TNgof         1920     NaN
# 13    7a6zoaBOya7nnPicmVFEx1         1920     NaN
# 14    2AWOgskypXnjLItNjzE6l5         1920     NaN
# 15    34quhtd2AfsCt4NUxC5WwU         1920     NaN
# 16    46JY9OYPi4hJ7oLIS0FZt0         1920     NaN
# 17    1HAK7hlSD1szWBiaC7PO7A         1920     NaN
# 18    4HYmmG8uHL2hP4zSFWavKF         1920     NaN
# 19    67WjqZ50Q9WmLMW62qfDdL         1920     NaN
# 20    7FZnWeEpRXMXXUiynwQKso         1920     NaN
# 21    35Isk2sBRwDbvg1YEshvOv         1920     NaN
# 22    4lDjkpUrpWlMFofIpzuExK         1920     NaN
# 23    4Lb0u3JwC4EWQXugQKGphZ         1920     NaN
# 24    0sj3QeaCpacCfxL4c5TQBl         1920     NaN
# 572   5Vjq62elGoOE69kZqzhb89         1920     NaN
# 573   0ojvOshbJWnvrcPRgLVtg2         1920     NaN
# 574   6AxJZ75bEsE5AFKbKuoNNw         1920     NaN
# 700   2YhYGZJExSEpVb42iP8QYy         1920     NaN
# 702   2IgxNdqtmsYYXapyXx2W1I         1920     NaN
# 703   1X53lvmr9xqOUM1OdHmuyV         1920     NaN
# 704   0hc7J9ePNVldWCyWHO9o8d         1920     NaN
# 705   1rPhYhsZZdGWBFMxRfUO0Q         1920     NaN
# 706   0xuQIxmGB2VtPpNmvoFwN6         1920     NaN
# 707   1xg2OnZRrlgZtRAxCmUD7Q         1920     NaN
# 708   5eQkGH45HAVFmNBvgDd9PR         1920     NaN
# 709   5ZUJWkNW1XLLpeksCwxQ5Z         1920     NaN
# 710   6Oy05GGNFNTfIGTiKXaP5d         1920     NaN
# 711   00oPGAsi8uXxw4NTgUswjd         1920     NaN
# 712   6GJLaNoKrv91Gs8lJsSBr5         1920     NaN
# 713   1uNrgArNegg1YkIBpO1WAA         1920     NaN
# 714   0foSIokYETKBrEwjFLtpNM         1920     NaN
# 715   6AcsHxi5LOqNc91YKR9D32         1920     NaN
# 716   5fLAYpTAUX7wVylCxLMV73         1920     NaN
# 717   0rVTAgxzUlDt4TDfnY5New         1920     NaN
# 718   0z3VTsaNJw03MpfGauyyO7         1920     NaN
# 719   416L1rx98FmP04oTjq1DaO         1920     NaN
# 720   5a8HNRcfWpYhKg5rvhmCOl         1920     NaN
# 721   3IB2mckzUN4N3y3ji7jWtQ         1920     NaN
# 722   3ThBM6hNCrLiEhHNNypk58         1920     NaN
# 723   4JPYUK6hNL36chDMkWRFVk         1920     NaN
# 724   2onqLWLNgOfepvtQxm6yq9         1920     NaN
# 825   2lPgRiJE3LXsi9ABxNNVnV         1920     NaN
# 826   2PCiNuXDp5StM7fEmSLhPq         1920     NaN
# 827   686N4PnQfH8NKiisbrQznd         1920     NaN
# 828   44J1CFMxIyTPlevcDghAsk         1920     NaN
# 829   14YYUaft0fQCYn7IqL4FYV         1920     NaN
# 830   24pfUpoUsOo4XyPaHgPDBu         1920     NaN
# 1230  5Emq6oTLQBqI8QErCNCNM8         1920     NaN
# 1365  3hTCsugtAdgQGmTE6LkmVI         1920     NaN

# %%
data_df.head()

# %%
{
    "Track Name": track["name"],
    "Artist": artist["name"],
    "artists": [data["name"] for data in track["artists"]],
    "spotify_id": track["id"],
    "release_date": track["album"]["release_date"],
    "region": region
}
# Out:
# {'Track Name': 'After Dark (feat. Static Major & Ty Dolla $ign)',
#  'Artist': 'Drake',
#  'artists': ['Drake', 'Static Major', 'Ty Dolla $ign'],
#  'spotify_id': '3mvYQKm8h6M5K5h0nVPY9S',
#  'release_date': '2018-06-29'}

# %%
for year in range(1920,2021):
    print(year)
    data_dict = sp.search(q=f"year:{year}",
                          limit=50, type='artist')

    for artist in data_dict["artists"]["items"]:
        print(artist["name"])
        query = f"artist:{artist['name']}"
        print(query)
        track_dict = sp.search(q=query, limit=50)
#         print(track_dict)
        for track in track_dict["tracks"]["items"]:
            artists = [data["name"] for data in track["artists"]]
            print(track["album"]["release_date"])
#             print(track["name"])
        break
    break
# Out:
# 1920
# Berliner Philharmoniker
# artist:Berliner Philharmoniker
# 2003-07-01
# 2008-05-21
# 2020-04-14
# 2020-04-14
# 2008-01-07
# 2004-07-12
# 2008-05-21
# 2005-11-28
# 2008-01-07
# 2007-11-12
# 2002-07-01
# 2012-11-09
# 2008-01-07
# 2012-11-09
# 2020-04-14
# 2012-11-09
# 2008-01-07
# 2008-01-07
# 2012-11-09
# 2006-09-26
# 2012-10-03
# 2012-11-09
# 2012-11-09
# 2008-01-07
# 2006-03-01
# 2000
# 2012-11-09
# 2008-05-21
# 2019-11-22
# 2012-10-03
# 2007-11-12
# 2006-03-01
# 2004-07-12
# 2000
# 2017-05-26
# 2000
# 2008-05-21
# 2012-11-09
# 2019-12-27
# 2008-01-07
# 2012-11-09
# 2020-04-14
# 2012-11-09
# 2012-11-09
# 2012-11-09
# 2012-11-09
# 2020-04-14
# 2008-05-21
# 2008-01-07
# 2020-04-14
